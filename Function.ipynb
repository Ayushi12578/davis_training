# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi12578/davis_training/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Function to add two numbers
def addnumber(x,y):
   return(x+y)

#main program
a = int(input("Enter a number :"))
b = int(input("Enter a number :"))
print("Sum",addnumber(a,b))
# Out:
# Enter a number :25
# Enter a number :50
# Sum is 75

# %%
#To check number is even or odd
def numbereven(num):
  if num % 2 ==0 :
    return("Even")
  else:
    return("odd")
a = int(input("Enter a number :"))
print("this number",numbereven(a))
# Out:
# Enter a number :10
# this number is Even

# %%
def calsum (x,y):
  return (x+y)
def calsub(x,y):
  return(x-y)
def calmul(x,y):
  return(x*y)
def caldiv(x,y):
  return(x/y)
def calrm(x,y):
  return(x%y)
a = int(input("Enter a first number :"))
b = int(input("Enter a second number :"))
print("Multiplication of this number is :",calmul(a,b))
# Out:
# Enter a first number :5
# Enter a second number :5
# Multiplication of this number is : 25
