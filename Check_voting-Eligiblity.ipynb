# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi12578/davis_training/blob/main/Check_voting-Eligiblity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#voting program check person is eligilbe or not
Age = int(input("Enetr your age :"))
if Age >=18:
  print("You are Eligible FOr vote")
else:
  print("You are not Eligible for vote")
  print("Try next time ,Thankyou")
# Out:
# Enetr your age :5
# You are not Eligible for vote
# Try next time ,Thankyou

# %%
def check_vote(age):
    if age >= 18:
        return "Eligible"
    else:
        return "Not Eligible"

a = int(input("enter age"))
print(check_vote(a))
# Out:
# enter age25
# Eligible

# %%
age = int(input("enter age"))

print("Eligible" if age >= 18 else "Not Eligible")
# Out:
# enter age55
# Eligible

# %%
age = int(input("eneter age"))

if age >= 18:
    print("Eligible")
if age < 18:
    print("Not Eligible")
# Out:
# eneter age100
# Eligible

# %%
age = int(input("eneter age"))

eligible = age >= 18

if eligible:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# eneter age40
# Eligible

# %%
age = int(input("eneter age"))

match age >= 18:
    case True:
        print("Eligible")
    case False:
        print("Not Eligible")
# Out:
# eneter age45
# Eligible

# %%
age = int(input())

if age < 0:
    print("Invalid age")
elif age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# -1
# Invalid age

# %%
age = int(input("enter age"))

while age < 0:
    age = int(input("Enter valid age: "))

if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# enter age45
# Eligible
