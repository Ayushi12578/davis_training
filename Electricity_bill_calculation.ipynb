# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi12578/davis_training/blob/main/Electricity_bill_calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#electricity bill calculation
Unit = int(input("Enter Unit"))
Bill = Unit *8
print("Total Bill is",Bill)
# Out:
# Enter Unit10
# Total Bill is 80
