# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi12578/davis_training/blob/main/Electricity_bill_calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#electricity bill calculation
Unit = int(input("Enter Unit"))
Bill = Unit *8
print("Total Bill is",Bill)
# Out:
# Enter Unit10
# Total Bill is 80

# %%
def bill(units):
    return units * 5

u = int(input("Enter unit"))
print(bill(u))
# Out:
# Enter unit10
# 50

# %%
units = int(input("Enter unit"))

while units < 0:
    units = int(input("Enter valid units: "))

print(units * 5)
# Out:
# Enter unit15
# 75

# %%
units = int(input("Enter unit"))
bill = 0

for count in range(1, units+1):
    bill = bill + 5

print(bill)
# Out:
# Enter unit45
# 225

# %%
units = int(input("Enter unit"))
bill = 0

for i in range(1, units+1):
    if i > 0:
        bill = bill + 5

print(bill)
# Out:
# Enter unit10
# 50

# %%
units = int(input("Enter unit"))
bill = 0

for i in range(1, units+1):
    print("Adding cost of unit", i)
    bill = bill + 5

print("Total bill =", bill)
# Out:
# Enter unit40
# Adding cost of unit 1
# Adding cost of unit 2
# Adding cost of unit 3
# Adding cost of unit 4
# Adding cost of unit 5
# Adding cost of unit 6
# Adding cost of unit 7
# Adding cost of unit 8
# Adding cost of unit 9
# Adding cost of unit 10
# Adding cost of unit 11
# Adding cost of unit 12
# Adding cost of unit 13
# Adding cost of unit 14
# Adding cost of unit 15
# Adding cost of unit 16
# Adding cost of unit 17
# Adding cost of unit 18
# Adding cost of unit 19
# Adding cost of unit 20
# Adding cost of unit 21
# Adding cost of unit 22
# Adding cost of unit 23
# Adding cost of unit 24
# Adding cost of unit 25
# Adding cost of unit 26
# Adding cost of unit 27
# Adding cost of unit 28
# Adding cost of unit 29
# Adding cost of unit 30
# Adding cost of unit 31
# Adding cost of unit 32
# Adding cost of unit 33
# Adding cost of unit 34
# Adding cost of unit 35
# Adding cost of unit 36
# Adding cost of unit 37
# Adding cost of unit 38
# Adding cost of unit 39
# ...

# %%
units = int(input("enetr the unit"))
bill = 0

for i in range(units):
    bill += 5

print("Bill =", bill)
# Out:
# enetr the unit5
# Bill = 25
