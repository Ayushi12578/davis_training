# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi12578/davis_training/blob/main/HCF_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to find out oput hcf
#input two number
num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))
#-----------------------------------------
while num2 != 0:
    if num1 > num2:
        num1 = num1 - num2
    else:
        num2 = num2 - num1
      #---------------------------
    print("HCF :",num1)
# Out:
# Enter first number:24
# Enter second number:32
# HCF : 24
# HCF : 16
# HCF : 8
# HCF : 8

# %%
# to Find greatest digit in number from given number
#input take from user
Num = input("Enter a number :")
greatest =0
for d in Num:
  if int(d) > greatest:
    greatest = int(d)
print("Greatest digit is ",greatest)
# Out:
# Enter a number :3729
# Greatest digit is  9

# %%
#to find factorial of number using for loop
#take inpur from user
num= int(input("Enter the number :"))
fact = 1
for i in range(1,num+1):
  fact=fact*i
print("Factorial =",fact)
# Out:
# Enter the number :5
# Factorial = 120

# %%
#sum of First n numbers
#take the input from user
number = int(input("Enter a number :"))

num = 0
for i in range(1,number+1):
  num = num + i
print("Sum OF natural number is",num)
# Out:
# Enter a number :3
# Sum OF natural number is 6

# %%
#Reverse a number using for loop
a = input("Enter a number :")
rev = ""
for i in a:
  rev = i +rev
print("Reverse number",rev)
# Out:
# Enter a number :5648
# Reverse number 8465

# %%
#Find even numeber
#take user input
num=int(input("ENter a number :"))
for i in range(1,num +1):
  if i % 2 == 0:
    print("Number is even",i)
# Out:
# ENter a number :15
# Number is even 2
# Number is even 4
# Number is even 6
# Number is even 8
# Number is even 10
# Number is even 12
# Number is even 14
