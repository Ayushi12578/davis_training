# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi12578/davis_training/blob/main/Shopkeeper_bill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# shopkeeper Bill calculation
price = float(input("Enter price: "))
discount = float(input("Enter discount %: "))

final_price = price - (price * discount / 100)

print("Final price =", final_price)
# Out:
# Enter price: 10
# Enter discount %: 5
# Final price = 9.5

# %%
price = float(input("Enter price:"))
discount = float(input("Enter discount %: "))

discount_amount = price * discount / 100
final_price = price - discount_amount

print(final_price)
# Out:
# Enter price:100
# Enter discount %: 5
# 95.0
